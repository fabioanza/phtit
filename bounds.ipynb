# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
times = np.linspace(0,10,1000)
var = np.linspace(0,1,10000)

# %%
tt = 20
plt.plot(var,np.abs(1-np.exp(1j*tt*var)),var,np.abs(np.sin(tt*np.abs(var))))

# %%
2*np.pi/10
# Out:
# 0.6283185307179586

# %%
def approx(x,t):

# %%
plt.plot(var,np.sin(var)/var)
# Out:
# /Users/fanza/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
